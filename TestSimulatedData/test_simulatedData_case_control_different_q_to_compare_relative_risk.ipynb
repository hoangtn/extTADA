# %%
sResult <- read.table("../data/SimulatedData/final.simulated.CaseControl.differentQ.txt",
                     header = FALSE)
colnames(sResult) <- c("Ntrio", "SimRR", "SimPi", "EstimatedRR", "EstimatedPi", "q0")

# %%
head(sResult)

#sResult <- sResult[sResult$SimRR > 1.9,]
# Out:
#   Ntrio SimRR SimPi EstimatedRR EstimatedPi    q0
# 1  5000   1.1  0.03    1.714885 0.015763979 1e-03
# 2  5000   1.1  0.03    1.592130 0.078992775 1e-04
# 3  5000   1.1  0.03    1.856893 0.010398031 5e-04
# 4  5000   1.1  0.05    1.674868 0.026429908 1e-03
# 5  5000   1.1  0.05    1.545999 0.307828838 2e-03
# 6  5000   1.1  0.05    2.247816 0.008370731 5e-04

# %%
library("ggplot2")
#p <- ggplot(mtcars, aes(wt, mpg))
library("gplots")
s1 <- sResult$SimRR
colorRR <- redgreen(length(s1))
p1 <- ggplot(sResult, aes(SimPi, EstimatedPi))

p1 + geom_point(aes(colour = as.factor(q0)))

p1 + geom_point(aes(colour = factor(SimRR)))
#shape = factor(SimRR)

p1 + geom_point(aes(colour = as.factor(SimPi)))
# Out:
# plot without title
# plot without title
# plot without title

# %%
p2 <- ggplot(sResult, aes(SimRR, EstimatedRR))

p2 + geom_point(aes(colour = as.factor(q0)))
# Out:
# plot without title

# %%
head(sResult)

sResult <- sResult[sResult$SimRR > 1.9,]

library("ggplot2")
#p <- ggplot(mtcars, aes(wt, mpg))
library("gplots")
s1 <- sResult$SimRR
colorRR <- redgreen(length(s1))
p1 <- ggplot(sResult, aes(SimPi, EstimatedPi))

p1 + geom_point(aes(colour = as.factor(q0)))

p1 + geom_point(aes(colour = factor(SimRR)))
#shape = factor(SimRR)

p1 + geom_point(aes(colour = as.factor(SimPi)))

p2 <- ggplot(sResult, aes(SimRR, EstimatedRR))

p2 + geom_point(aes(colour = as.factor(q0)))
# Out:
#    Ntrio SimRR SimPi EstimatedRR EstimatedPi    q0
# 74  5000   2.1  0.03    2.340857  0.03126261 1e-03
# 75  5000   2.1  0.03    2.369524  0.02602058 2e-03
# 76  5000   2.1  0.03    2.267657  0.05194806 1e-04
# 77  5000   2.1  0.03    2.456384  0.02608147 5e-04
# 78  5000   2.1  0.05    2.367070  0.04398014 1e-03
# 79  5000   2.1  0.05    2.312269  0.05219036 2e-03
# plot without title
# plot without title
# plot without title
# plot without title
