# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %% [markdown]
# #Use different algorithms
#
# ##Use NLOPT_GN_ISRES

# %%
#!gist -p Test_nloptr_for_FMRP_geneset_outer_dn_LoFandMis3.ipynb

# %%
# !gist -u https://gist.github.com/0e861451d30bffcc20c6 Test_nloptr_for_FMRP_geneset_outer_dn_LoFandMis3.ipynb
# Out:
# https://gist.github.com/0e861451d30bffcc20c6

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.nonlinearNLOPT_GN_ISRES.onlyDenovo.LoF.dnMis3.geneSet.FMRP.txt"
# fileN = "result.nloptr.outerProduct.nonlinearNLOPT_GN_ISRES.onlyDenovo.LoF.dnMis3.geneSet.FMRP.betaEqualOne.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 1000   11

# %%
# %%R -w 28 -h 28 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R
# round(apply(nloptr.result, 2, median), 3)
# Out:
#      V1      V2      V3      V4      V5      V6      V7      V8      V9     V10
#   0.173  20.053   1.000   6.496   1.000   0.183  21.620   1.000   5.533   1.001
#     V11
# 553.097

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# colNames <- c("pi", "gamma.dn.lof", "beta.lof", "gamma.dn.mis3", "beta.mis3")
# par(mfrow = c(2, 3))
# for (jj in 1:dimK){
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Estimated value',
#     main = paste("GN_ISRES: ", colNames[jj], "\nSpearman cor = ",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2), sep = ""),
#     ylim = range(nloptr.result[[jj]]),
#     col = 'blue')
#     abline(h = 0.06, col = 'red')
#     }
# Out:
# [1] 5

# %%
# %%R -w 28 -h 28 -u cm
#
# nloptr.result.1 <- nloptr.result
# #pairs(nloptr.result.1[c(V1, V2, V3)])

# %%
# %%R
#
# hist(nloptr.result[[dimK + 1]], 100)

# %%
##Beta ~ 1

# %%
# %%R -w 28 -h 28 -u cm
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.nonlinearNLOPT_GN_ISRES.onlyDenovo.LoF.dnMis3.geneSet.FMRP.txt"
# fileN = "result.nloptr.outerProduct.nonlinearNLOPT_GN_ISRES.onlyDenovo.LoF.dnMis3.geneSet.FMRP.betaEqualOne.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
#
# print(dim(nloptr.result))
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }
# hist(nloptr.result[[dimK + 1]], 100)
# Out:
# [1] 1000   11

# %% [markdown]
# ##Use NLOPT_LN_COBYLA

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.nonlinearNLOPT_LN_COBYLA.onlyDenovo.LoF.dnMis3.geneSet.FMRP.txt"
# fileN = "result.nloptr.outerProduct.nonlinearNLOPT_LN_COBYLA.onlyDenovo.LoF.dnMis3.geneSet.FMRP.betaEqualOne.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 1000   11

# %%
# %%R -w 28 -h 28 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# colNames <- c("pi", "gamma.dn.lof", "beta.lof", "gamma.dn.mis3", "beta.mis3")
# par(mfrow = c(2, 3))
# for (jj in 1:dimK){
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Estimated value',
#     main = paste("LN_COBYLA: ", colNames[jj], "\nSpearman cor = ",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2), sep = ""),
#     ylim = range(nloptr.result[[jj]]),
#     col = 'blue')
#     abline(h = 0.06, col = 'red')
#     }
# Out:
# [1] 5

# %% [markdown]
# ##Use NLMMINB

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.nonlinearNLMMINB.onlyDenovo.LoF.dnMis3.geneSet.FMRP.txt"
# fileN = "result.nloptr.outerProduct.nonlinearNLMMINB.onlyDenovo.LoF.dnMis3.geneSet.FMRP.betaEqualOne.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 1000   11

# %%
# %%R -w 28 -h 28 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R
# round(apply(nloptr.result, 2, median), 3)
# Out:
#      V1      V2      V3      V4      V5      V6      V7      V8      V9     V10
#   0.173  20.053   1.000   6.496   1.000   0.189  20.893   0.990   5.388   1.010
#     V11
# 552.837

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# colNames <- c("pi", "gamma.dn.lof", "beta.lof", "gamma.dn.mis3", "beta.mis3")
# par(mfrow = c(2, 3))
# for (jj in 1:dimK){
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Estimated value',
#     main = paste("NLMMINB: ", colNames[jj], "\nSpearman cor = ",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2), sep = ""),
#     ylim = range(nloptr.result[[jj]]),
#     col = 'blue')
#     abline(h = 0.06, col = 'red')
#     }
# Out:
# [1] 5
