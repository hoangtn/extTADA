# %%
# %load_ext rpy2.ipython

# %% [markdown]
# #Use different algorithms
#
# ##Use NLOPT_GN_ISRES

# %%
#!gist -p Test_nloptr_for_all20000_geneset_outer_both_LoF_and_dnMis3_data2013.ipynb

# %%
# !gist -u https://gist.github.com/03a0185d3b7d97b564ae Test_nloptr_for_all20000_geneset_outer_both_LoF_and_dnMis3_data2013.ipynb
# Out:
# https://gist.github.com/03a0185d3b7d97b564ae

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.TADA2013.nonlinearNLOPT_GN_ISRES.bothLoF.dnMis3.geneSet.FMRP.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
# Out:
# data.table 1.9.4  For help type: ?data.table
# *** NB: by=.EACHI is now explicit. See README to restore previous behaviour.

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 200  11

# %%
# %%R -w 28 -h 28 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R
# round(apply(nloptr.result, 2, median), 3)
# Out:
#       V1       V2       V3       V4       V5       V6       V7       V8
#    0.056   19.556    1.000    6.408    1.000    0.058   19.392    1.000
#       V9      V10      V11
#    5.518    1.000 2082.084

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# par(mfrow = c(3, 2))
# for (jj in 1:dimK)
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Value',
#     main = round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2),
#     ylim = range(nloptr.result[[jj]]))
# Out:
# [1] 5

# %%
# %%R -w 28 -h 28 -u cm
#
# nloptr.result.1 <- nloptr.result
# #pairs(nloptr.result.1[c(V1, V2, V3)])

# %%
# %%R
#
# hist(nloptr.result[[dimK + 1]], 100)

# %%
##Beta ~ 1

# %% [markdown]
# ##Use NLOPT_LN_COBYLA

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
#
# fileN = "result.nloptr.outerProduct.TADA2013.nonlinearNLOPT_LN_COBYLA.both.all.LoF.Mis3.geneSet.all20000.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 100  35

# %%
# %%R -w 28 -h 28 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# par(mfrow = c(3, 2))
# for (jj in 1:dimK)
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Value',
#     main = round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2),
#     ylim = range(nloptr.result[[jj]]))
# Out:
# [1] 17

# %% [markdown]
# ##Use NLMMINB

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.TADA2013.nonlinearNLMMINB.both.all.LoF.Mis3.geneSet.all20000.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 25 23

# %%
# %%R -w 28 -h 28 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R
# round(apply(nloptr.result, 2, median), 3)
# Out:
#        V1        V2        V3        V4        V5        V6        V7        V8
#     0.054    16.675     1.041     3.403     3.749     0.693 12719.748     0.788
#        V9       V10       V11       V12       V13       V14       V15       V16
#   760.377     6.727     2.992     0.080    14.802     0.900     3.740     6.000
#       V17       V18       V19       V20       V21       V22       V23
#     1.200 12716.861     0.515   799.146     4.401     1.134 45046.852

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# par(mfrow = c(3, 2))
# for (jj in 1:dimK)
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Value',
#     main = round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2),
#     ylim = range(nloptr.result[[jj]]))
# Out:
# [1] 11
