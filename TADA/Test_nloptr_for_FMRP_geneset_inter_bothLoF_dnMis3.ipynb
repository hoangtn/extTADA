# %%
# %load_ext rpy2.ipython

# %%
#!gist -p Test_nloptr_for_FMRP_geneset_inter_bothLoF_dnMis3.ipynb

# %%
# !gist -u https://gist.github.com/f9d697cf3ed19ee098f8 Test_nloptr_for_FMRP_geneset_inter_bothLoF_dnMis3.ipynb
# Out:
# https://gist.github.com/f9d697cf3ed19ee098f8

# %% [markdown]
# ##Use NLMMINB

# %%
# %%R
# library("data.table")
# ##Only FMRP gene set
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.geneSet.FMRP.txt")
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.interProduct.geneSet.FMRP.txt")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.interProduct.nonlinearNLMMINB.bothLoF.dnMis3.geneSet.FMRP.new1.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
# ##All 20000 genes
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.all20000genes.txt")
# Out:
# data.table 1.9.4  For help type: ?data.table
# *** NB: by=.EACHI is now explicit. See README to restore previous behaviour.

# %%
# %%R
# print(dim(nloptr.result))
# head(nloptr.result)
# Out:
# [1] 100  23
#            V1       V2        V3       V4       V5        V6        V7
# 1: 0.22444169 16.83533 1.0008447 3.622194 4.441433 1.2184352  5257.158
# 2: 0.27108769 10.93734 1.0003020 4.002816 3.241129 0.5982455  7730.633
# 3: 0.08466395 22.08297 0.9999335 4.538285 5.045947 1.0330896  6759.204
# 4: 0.09632477 14.06511 0.9999512 3.887167 2.754132 0.5221374  6494.179
# 5: 0.18755135 15.64695 0.9995690 3.471496 4.571828 1.2864850 12979.760
# 6: 0.28403186 10.91106 0.9999231 4.948838 5.369364 0.5688844  6304.519
#           V8        V9      V10       V11       V12      V13   V14     V15
# 1: 0.4408234 1759.7349 4.036410 1.0009843 0.1625925 24.30108 0.999 2.00000
# 2: 0.2995143  584.3548 5.749186 1.0004034 0.1744054 22.58894 0.999 2.00000
# 3: 0.4825824 1692.2635 2.625353 1.0001106 0.1712661 23.05481 0.999 2.00000
# 4: 0.6517825 2751.7289 7.583610 0.9995814 0.1699828 23.23694 0.999 2.00000
# 5: 0.2293267  557.5816 3.901273 0.9996110 0.1656882 23.55865 0.999 2.32052
# 6: 0.5163665 1977.7608 2.691647 0.9994954 0.1692133 23.34576 0.999 2.00000
#         V16       V17       V18       V19  V20      V21   V22      V23
# 1: 3.263407 0.8201562  5332.765 0.7963940 3000 5.815552 1.001 2639.219
# 2: 4.377563 1.0706658  7837.488 0.8000000 3000 5.612567 1.001 2639.656
# 3: 3.345768 0.9661862  6757.534 0.8000000 3000 5.664978 1.001 2639.473
# 4: 3.283861 0.9396790  6493.376 0.7994880 3000 5.686658 1.001 2639.421
# 5: 6.000000 1.3000000 12935.124 0.8000000 3000 5.760821 1.001 2640.014
# 6: 3.263526 0.9254662  6351.795 0.7991061 3000 5.699758 1.001 2639.393

# %%
# %%R -w 28 -h 76 -u cm
# par(mfrow = c(12, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 50, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R -w 28 -h 30 -u cm
#
# par(mfrow = c(4, 3))
# colNames <- c("pi", "gamma.mean.lof.dn", "beta.lof.dn", "gamma.mean.lof.cc", "beta.lof.cc",
#              "rho1.lof", "nu1.lof", "rho0.lof", "nu0.lof",
#               "gamma.mean.mis3.dn", "beta.lof.dn")
# for (jj in 1:11)
# plot(nloptr.result[[jj]], nloptr.result[[jj + 11]],
#      xlab = 'initial value', ylab = 'Value',
#     main = paste(colNames[jj], "\n",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + 11]], method = "spearman"), 2), sep = ""),
#     col = 'blue', xlim = range(nloptr.result[[jj]]),
#     ylim = range(nloptr.result[[jj]])    )

# %% [markdown]
# ##Change very big range
# 	lowLimit = c(0.050, 10, 0.50, 1, 0.1, 0.3,  1000, 0.10,  100,  1, 0.2)
# 	x1.6 <-    c(0.055, 18, 0.95, 3, 5.0, 0.6, 12000, 0.45,  600,  4, 1.2)
# 	highLimit= c(0.300, 30, 3.50, 5,  10, 2.3, 35000, 3.80, 30000, 10, 6.2)

# %%
# %%R
# library("data.table")
# ##Only FMRP gene set
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.geneSet.FMRP.txt")
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.interProduct.geneSet.FMRP.txt")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.interProduct.nonlinearNLMMINB.bothLoF.dnMis3.geneSet.FMRP.new2.largeRange.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
# ##All 20000 genes
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.all20000genes.txt")

# %%
# %%R -w 28 -h 30 -u cm
#
# par(mfrow = c(4, 3))
# colNames <- c("pi", "gamma.mean.lof.dn", "beta.lof.dn", "gamma.mean.lof.cc", "beta.lof.cc",
#              "rho1.lof", "nu1.lof", "rho0.lof", "nu0.lof",
#               "gamma.mean.mis3.dn", "beta.lof.dn")
# for (jj in 1:11)
# plot(nloptr.result[[jj]], nloptr.result[[jj + 11]],
#      xlab = 'initial value', ylab = 'Value',
#     main = paste(colNames[jj], "\n",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + 11]], method = "spearman"), 2), sep = ""),
#     col = 'blue', xlim = range(nloptr.result[[jj]]),
#     ylim = range(nloptr.result[[jj]])    )

# %% [markdown]
# ##New range
# lowLimit = c(0.050, 10, 0.50, 1, 0.1, 0.3,  1000, 0.10,  100,  1, 0.2)
#
# x1.6 <-    c(0.055, 18, 0.95, 3, 5.0, 0.6, 12000, 0.45,  600,  4, 1.2)
#
# highLimit= c(0.300, 30, 3.50, 5,  10, 2.3, 15000, 3.80, 2000, 10, 6.2)

# %%
# %%R
# library("data.table")
# ##Only FMRP gene set
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.geneSet.FMRP.txt")
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.interProduct.geneSet.FMRP.txt")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.interProduct.nonlinearNLMMINB.bothLoF.dnMis3.geneSet.FMRP.new3.largeRange.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
# ##All 20000 genes
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.all20000genes.txt")

# %%
# %%R -w 28 -h 30 -u cm
#
# par(mfrow = c(4, 3))
# colNames <- c("pi", "gamma.mean.lof.dn", "beta.lof.dn", "gamma.mean.lof.cc", "beta.lof.cc",
#              "rho1.lof", "nu1.lof", "rho0.lof", "nu0.lof",
#               "gamma.mean.mis3.dn", "beta.lof.dn")
# for (jj in 1:11)
# plot(nloptr.result[[jj]], nloptr.result[[jj + 11]],
#      xlab = 'initial value', ylab = 'Value',
#     main = paste(colNames[jj], "\n",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + 11]], method = "spearman"), 2), sep = ""),
#     col = 'blue', xlim = range(nloptr.result[[jj]]),
#     ylim = range(nloptr.result[[jj]])    )

# %% [markdown]
# ###New
#
# lowLimit = c(0.050, 10, 0.50, 1, 0.1, 0.3,  1000, 0.10,  100,  1, 0.2)
#
# x1.6 <-    c(0.055, 18, 0.95, 3, 5.0, 0.6, 12000, 0.45,  600,  4, 1.2)
#
# highLimit= c(0.300, 30, 3.50, 5,  10, 1.0, 15000, 1.00, 2000, 10, 6.2)

# %%
# %%R
# library("data.table")
# ##Only FMRP gene set
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.geneSet.FMRP.txt")
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.interProduct.geneSet.FMRP.txt")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.interProduct.nonlinearNLMMINB.bothLoF.dnMis3.geneSet.FMRP.new4.largeRange.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
# ##All 20000 genes
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.all20000genes.txt")

# %%
# %%R -w 28 -h 30 -u cm
#
# par(mfrow = c(4, 3))
# colNames <- c("pi", "gamma.mean.lof.dn", "beta.lof.dn", "gamma.mean.lof.cc", "beta.lof.cc",
#              "rho1.lof", "nu1.lof", "rho0.lof", "nu0.lof",
#               "gamma.mean.mis3.dn", "beta.lof.dn")
# for (jj in 1:11)
# plot(nloptr.result[[jj]], nloptr.result[[jj + 11]],
#      xlab = 'initial value', ylab = 'Value',
#     main = paste(colNames[jj], "\n",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + 11]], method = "spearman"), 2), sep = ""),
#     col = 'blue', xlim = range(nloptr.result[[jj]]),
#     ylim = range(nloptr.result[[jj]])    )

# %% [markdown]
# ###New 5
#
#         lowLimit = c(0.050, 10, 0.50, 2, 0.5, 0.3,  1000, 0.10,  100,  1, 0.2)
#
#         x1.6 <-    c(0.055, 18, 0.95, 3, 5.0, 0.6, 12000, 0.45,  600,  4, 1.2)
#
#         highLimit= c(0.300, 30, 3.50, 5, 5.0, 1.0, 15000, 1.00, 2000, 10, 6.2)

# %%
# %%R
# library("data.table")
# ##Only FMRP gene set
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.geneSet.FMRP.txt")
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.interProduct.geneSet.FMRP.txt")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.interProduct.nonlinearNLMMINB.bothLoF.dnMis3.geneSet.FMRP.new5.largeRange.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
# ##All 20000 genes
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.all20000genes.txt")

# %%
# %%R -w 28 -h 30 -u cm
#
# par(mfrow = c(4, 3))
# colNames <- c("pi", "gamma.mean.lof.dn", "beta.lof.dn", "gamma.mean.lof.cc", "beta.lof.cc",
#              "rho1.lof", "nu1.lof", "rho0.lof", "nu0.lof",
#               "gamma.mean.mis3.dn", "beta.lof.dn")
# for (jj in 1:11)
# plot(nloptr.result[[jj]], nloptr.result[[jj + 11]],
#      xlab = 'initial value', ylab = 'Value',
#     main = paste(colNames[jj], "\n",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + 11]], method = "spearman"), 2), sep = ""),
#     col = 'blue', xlim = range(nloptr.result[[jj]]),
#     ylim = range(nloptr.result[[jj]])    )

# %% [markdown]
# ###Next
#        lowLimit = c(0.050, 10, 0.50, 2, 0.5, 0.3,  1000, 0.10,  100,  1, 0.2)
#
#         x1.6 <-    c(0.055, 18, 0.95, 3, 5.0, 0.6, 12000, 0.45,  600,  4, 1.2)
#
#        highLimit= c(0.300, 30, 3.50, 5, 5.0, 1.5, 15000, 1.50, 2000, 10, 6.2)

# %%
# %%R
# library("data.table")
# ##Only FMRP gene set
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.geneSet.FMRP.txt")
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.interProduct.geneSet.FMRP.txt")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.interProduct.nonlinearNLMMINB.bothLoF.dnMis3.geneSet.FMRP.new6.largeRange.tx"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
# ##All 20000 genes
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.all20000genes.txt")

# %%
# %%R -w 28 -h 30 -u cm
#
# par(mfrow = c(4, 3))
# colNames <- c("pi", "gamma.mean.lof.dn", "beta.lof.dn", "gamma.mean.lof.cc", "beta.lof.cc",
#              "rho1.lof", "nu1.lof", "rho0.lof", "nu0.lof",
#               "gamma.mean.mis3.dn", "beta.lof.dn")
# for (jj in 1:11)
# plot(nloptr.result[[jj]], nloptr.result[[jj + 11]],
#      xlab = 'initial value', ylab = 'Value',
#     main = paste(colNames[jj], "\n",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + 11]], method = "spearman"), 2), sep = ""),
#     col = 'blue', xlim = range(nloptr.result[[jj]]),
#     ylim = range(nloptr.result[[jj]])    )

# %% [markdown]
# ##Use rho1=rho0=0.66 and 1947

# %%
# %%R
# library("data.table")
# ##Only FMRP gene set
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.geneSet.FMRP.txt")
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.interProduct.geneSet.FMRP.txt")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.interProduct.nonlinearNLMMINB.bothLoF.dnMis3.geneSet.FMRP.new7.largeRange.userho1EqualRhoIn2014.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
# ##All 20000 genes
# #nloptr.result <- fread("/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/result.nloptr.outerProduct.all20000genes.txt")

# %%
# %%R -w 28 -h 30 -u cm
#
# par(mfrow = c(4, 3))
# colNames <- c("pi", "gamma.mean.lof.dn", "beta.lof.dn", "gamma.mean.lof.cc", "beta.lof.cc",
#              "rho1.lof", "nu1.lof", "rho0.lof", "nu0.lof",
#               "gamma.mean.mis3.dn", "beta.lof.dn")
# for (jj in 1:11)
# plot(nloptr.result[[jj]], nloptr.result[[jj + 11]],
#      xlab = 'initial value', ylab = 'Value',
#     main = paste(colNames[jj], "\n",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + 11]], method = "spearman"), 2), sep = ""),
#     col = 'blue', xlim = range(nloptr.result[[jj]]),
#     ylim = range(nloptr.result[[jj]])    )
