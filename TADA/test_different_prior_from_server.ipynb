# %%
# %load_ext rpy2.ipython

# %%
# !ls /usr/data/Documents/SaveDataFromServer/RunRjags/resultRunXem.gamma* > listRData.txt

# %%
# %%R
#
# listRData <- readLines("listRData.txt")
#
# for (ii in 1:length(listRData)){
#     load(listRData[ii])
#
#     ###
#     x2 <- unlist(strsplit(listRData[ii], ".", fixed = TRUE))
#     mLabel <-  paste(x2[6], x2[7], sep = "-")
#
#     apply(outData, 2, function(x){
#     par(mfrow = c(1, 2))
#     plot(density(x), main = mLabel)
#     plot(x, main = mLabel)
#
# })
#
# }

# %%
# !pwd
# Out:
# /usr/data/Documents/GitHub/TestR/HBproject/extTADA

# %%
#!gist -p test_different_prior_from_server.ipynb

# %%
# !gist -u https://gist.github.com/8f7f13e8d497aa09b721 test_different_prior_from_server.ipynb
# Out:
# https://gist.github.com/8f7f13e8d497aa09b721
