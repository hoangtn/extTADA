# %%
# %load_ext rpy2.ipython

# %% [markdown]
# #Use different algorithms
#
# ##Use NLOPT_GN_ISRES

# %%
#!gist -p Test_nloptr_for_all20000_geneset_outer_only_denovo_LoFandMis3_data2013.ipynb

# %%
# !gist -u https://gist.github.com/ee472c06cf22d2658784 Test_nloptr_for_all20000_geneset_outer_only_denovo_LoFandMis3_data2013.ipynb
# Out:
# https://gist.github.com/ee472c06cf22d2658784

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.TADA2013.nonlinearNLOPT_GN_ISRES.onlyDenovo.LoF.mis3.geneSet.all20000.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))
# Out:
# data.table 1.9.4  For help type: ?data.table
# *** NB: by=.EACHI is now explicit. See README to restore previous behaviour.

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 200  11

# %%
# %%R -w 28 -h 56 -u cm
# par(mfrow = c(9, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R
# round(apply(nloptr.result, 2, median), 3)
# Out:
#       V1       V2       V3       V4       V5       V6       V7       V8
#    0.056   19.556    1.000    6.408    1.000    0.058   19.392    1.000
#       V9      V10      V11
#    5.518    1.000 2082.084

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# colNames <- c("pi", "gamma.dn.lof", "beta.lof", "gamma.dn.mis3", "beta.mis3")
# par(mfrow = c(2, 3))
# for (jj in 1:dimK){
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Estimated value',
#     main = paste("GN_ISRES: ", colNames[jj], "\nSpearman cor = ",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2), sep = ""),
#     ylim = range(nloptr.result[[jj]]),
#     col = 'blue')
#     abline(h = 0.06, col = 'red')
#     }
# Out:
# [1] 5

# %%
# %%R -w 28 -h 28 -u cm
#
# nloptr.result.1 <- nloptr.result
# #pairs(nloptr.result.1[c(V1, V2, V3)])

# %%
# %%R
#
# hist(nloptr.result[[dimK + 1]], 100)

# %%
##Beta ~ 1

# %% [markdown]
# ##Use NLOPT_LN_COBYLA

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
#
# fileN = "result.nloptr.outerProduct.TADA2013.nonlinearNLOPT_LN_COBYLA.onlyDenovo.LoF.mis3.geneSet.all20000.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 200  11

# %%
# %%R -w 28 -h 58 -u cm
# par(mfrow = c(4, 2))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# colNames <- c("pi", "gamma.dn.lof", "beta.lof", "gamma.dn.mis3", "beta.mis3")
# par(mfrow = c(2, 3))
# for (jj in 1:dimK){
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Estimated value',
#     main = paste("LN_COBYLA: ", colNames[jj], "\nSpearman cor = ",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2), sep = ""),
#     ylim = range(nloptr.result[[jj]]),
#     col = 'blue')
#     abline(h = 0.06, col = 'red')
#     }
# Out:
# [1] 5

# %% [markdown]
# ##Use NLMMINB

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.TADA2013.nonlinearNLMMINB.onlyDenovo.LoF.mis3.geneSet.all20000.txt"
# fileN = "result.nloptr.outerProduct.nonlinearNLMMINB.bothLoF.dnMis3.geneSet.FMRP.largeRange.txt"
# fileN = "result.nloptr.outerProduct.nonlinearNLMMINB.onlyDenovo.LoF.dnMis3.geneSet.all20000.LargeRangesInitialValues.new1.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
#
# nloptr.result <- head(nloptr.result, 100)
# #nloptr.result <- nloptr.result[V1 < 0.08]
# #nloptr.result <- nloptr.result[V2 > 15]
# #print(dim(nloptr.result))

# %%
# %%R -w 28 -h 38 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R
# round(apply(nloptr.result, 2, median), 3)
# Out:
#       V1       V2       V3       V4       V5       V6       V7       V8
#    0.107   19.424   16.928    6.196   12.958    0.054   20.801   18.316
#       V9      V10      V11
#    5.951   27.248 2081.904

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# par(mfrow = c(2, 3))
# colNames <- c("pi", "gamma.dn.lof", "beta.lof", "gamma.dn.mis3", "beta.mis3")
# for (jj in 1:dimK){
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Estimated value',
#     main = paste("NLMMINB: ", colNames[jj], "\nSpearman cor = ",
#                  round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2), sep = ""),
#     ylim = range(nloptr.result[[jj]]),
#     col = 'blue')
#     abline(h = 0.06, col = 'red')
#     }
# Out:
# [1] 5
