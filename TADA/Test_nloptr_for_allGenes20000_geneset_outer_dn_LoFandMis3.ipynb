# %%
# %load_ext rpy2.ipython

# %% [markdown]
# #Use different algorithms
#
# ##Use NLOPT_GN_ISRES

# %%
#!gist -p Test_nloptr_for_allGenes20000_geneset_outer_dn_LoFandMis3.ipynb
# Out:
# https://gist.github.com/3e09745c74f33566eb71

# %%
# !gist -u https://gist.github.com/3e09745c74f33566eb71 Test_nloptr_for_allGenes20000_geneset_outer_dn_LoFandMis3.ipynb
# Out:
# https://gist.github.com/3e09745c74f33566eb71

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.nonlinearNLOPT_GN_ISRES.onlyDenovo.LoF.dnMis3.geneSet.all20000.txt"
# #fileN <- "result.nloptr.outerProduct.nonlinearNLMMINB.onlyDenovo.LoF.dnMis3.geneSet.all20000.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 200  11

# %%
# %%R -w 28 -h 28 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R
# round(apply(nloptr.result, 2, median), 3)
# Out:
#       V1       V2       V3       V4       V5       V6       V7       V8
#    0.058   20.671    1.052    6.465    1.344    0.040   25.874    1.026
#       V9      V10      V11
#    6.389    1.449 4508.730

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# par(mfrow = c(3, 2))
# for (jj in 1:dimK)
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Value',
#     main = round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2),
#     ylim = range(nloptr.result[[jj]]))
# Out:
# [1] 5

# %%
# %%R -w 28 -h 28 -u cm
#
# nloptr.result.1 <- nloptr.result
# #pairs(nloptr.result.1[c(V1, V2, V3)])

# %%
# %%R
#
# hist(nloptr.result[[dimK + 1]], 100)

# %% [markdown]
# ##Use NLOPT_LN_COBYLA (not run for all genes)

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.nonlinearNLOPT_LN_COBYLA.onlyDenovo.LoF.dnMis3.geneSet.FMRP.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 4000   11

# %%
# %%R -w 28 -h 28 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# par(mfrow = c(3, 2))
# for (jj in 1:dimK)
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Value',
#     main = round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2),
#     ylim = range(nloptr.result[[jj]]))
# Out:
# [1] 5

# %% [markdown]
# ##Use NLMMINB

# %%
# %%R
# library("data.table")
#
# dirFile = "/usr/data/Documents/SaveDataFromServer/CombinedDataThreeDiseases/"
# fileN = "result.nloptr.outerProduct.nonlinearNLMMINB.onlyDenovo.LoF.dnMis3.geneSet.all20000.txt"
# nloptr.result <- fread(paste(dirFile, fileN, sep = ""))

# %%
# %%R
# print(dim(nloptr.result))
# Out:
# [1] 200  11

# %%
# %%R -w 28 -h 28 -u cm
# par(mfrow = c(6, 4))
# for (ii in 1:dim(nloptr.result)[2]){
#     hist(nloptr.result[[ii]], 100, main = ii)
#     plot(density(nloptr.result[[ii]]), main = ii)
# }

# %%
# %%R
# round(apply(nloptr.result, 2, median), 3)
# Out:
#       V1       V2       V3       V4       V5       V6       V7       V8
#    0.058   20.671    1.052    6.465    1.344    0.039   26.891    0.900
#       V9      V10      V11
#    6.561    2.000 4508.213

# %%
# %%R -w 28 -h 30 -u cm
#
# dimK <- floor(dim(nloptr.result)[2]/2)
#
# print(dimK)
# par(mfrow = c(3, 2))
# for (jj in 1:dimK)
# plot(nloptr.result[[jj]], nloptr.result[[jj + dimK]], xlab = 'initial value', ylab = 'Value',
#     main = round(cor(nloptr.result[[jj]], nloptr.result[[jj + dimK]], method = "spearman"), 2),
#     ylim = range(nloptr.result[[jj]]))
# Out:
# [1] 5
