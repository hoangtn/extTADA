# %%
# %load_ext rpy2.ipython
# Out:
# The rpy2.ipython extension is already loaded. To reload it, use:
#   %reload_ext rpy2.ipython

# %%
# !ls /usr/data/Documents/SaveDataFromServer/RunRjags/result.NEGATIVEbinomail.gamma.beta* > listRData.txt

# %%
# %%R -w 28 -h 10 -u cm
#
# listRData <- readLines("listRData.txt")
#
# for (ii in 1:length(listRData)){
#     load(listRData[ii])
#
#     ###
#     x2 <- unlist(strsplit(listRData[ii], ".", fixed = TRUE))
#     mLabel <-  paste(x2[7], x2[8], sep = "-")
#
#     apply(outData, 2, function(x){
#     par(mfrow = c(1, 2))
#     plot(density(x), main = mLabel)
#     plot(x, main = mLabel)
#
# })
#
# }

# %%
# %%R
# listRData <- readLines("listRData.txt")
#
# for (ii in 1:length(listRData)){
#     load(listRData[ii])
#
#     ###
#     x2 <- unlist(strsplit(listRData[ii], ".", fixed = TRUE))
#     mLabel <-  paste(x2[7], x2[8], sep = "-")
#
#     print(listRData[ii])
#     print(round(apply(outData, 2, mean), 3))
#
#
# }
# Out:
# [1] "/usr/data/Documents/SaveDataFromServer/RunRjags/result.NEGATIVEbinomail.gamma.beta.p1.p2.beta.beta.RData"
# gamma.mean.dn.null  beta.mean.dn.null  gamma.mean.dn.alt   beta.mean.dn.alt
#              1.000         100000.000             19.189              0.449
#              p1[1]              p1[2]
#              0.946              0.054
# [1] "/usr/data/Documents/SaveDataFromServer/RunRjags/result.NEGATIVEbinomail.gamma.beta.p1.p2.normal.normal.RData"
# gamma.mean.dn.null  beta.mean.dn.null  gamma.mean.dn.alt   beta.mean.dn.alt
#              1.000         100000.000             24.436              0.999
#              p1[1]              p1[2]
#              0.958              0.042
# [1] "/usr/data/Documents/SaveDataFromServer/RunRjags/result.NEGATIVEbinomail.gamma.beta.p1.p2.uniform.uniform.RData"
# gamma.mean.dn.null  beta.mean.dn.null  gamma.mean.dn.alt   beta.mean.dn.alt
#              1.000         100000.000             30.749              0.588
# ...

# %%
# !pwd
# Out:
# /usr/data/Documents/GitHub/TestR/HBproject/extTADA

# %%
#!gist -p test_different_prior_from_server_use_twoNegativeBinomail.ipynb

# %%
# !gist -u https://gist.github.com/53bb190806a58d1ed889 test_different_prior_from_server_use_twoNegativeBinomail.ipynb
# Out:
# https://gist.github.com/53bb190806a58d1ed889
