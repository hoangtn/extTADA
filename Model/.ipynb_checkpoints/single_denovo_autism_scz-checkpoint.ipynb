# %%
# %load_ext rpy2.ipython

# %%
# %%R
# load("/usr/data/Documents/SaveDataFromServer/rstan_scz_and_autism_LoF_missense_denovo_add_stan2coda.RData")
# Out:
# ...
# by .GlobalEnv when processing object ‘testFitP’

# %%
# %%R
# ls()
# Out:
#  [1] "a1"                       "allPar"
#  [3] "b1"                       "beta.CC"
#  [5] "beta.dn"                  "casecontrol"
#  [7] "counts"                   "data"
#  [9] "data0"                    "data1"
# [11] "f"                        "f1"
# [13] "fit"                      "fit2"
# [15] "fitLoF"                   "fitLoFAutism"
# [17] "fitLoFAutismS"            "fitLoFscz"
# [19] "fitLoFsczS"               "fitMissensesAutism"
# [21] "fitMissensesAutismS"      "fitMissensescz"
# [23] "fitMissensesczS"          "gamma.mean.CC"
# [25] "gamma.mean.dn"            "hyperpar"
# [27] "ii"                       "internalSingleMixPoisson"
# [29] "l"                        "lof"
# [31] "lof1"                     "m"
# [33] "mis3"                     "mis31"
# [35] "mixdata3"                 "mu.frac"
# [37] "mutLoF"                   "mutMis3"
# [39] "N"                        "n1"
# [41] "ncase"                    "nChain"
# [43] "nCore"                    "nctrl"
# ...

# %%
# %%R -w 28 -h 28 -u cm
# ### Autism LoF
# library("coda")
# plot(fitLoFAutismS)

# %%
# %%R -w 28 -h 28 -u cm
# ### Autism missense
# library("coda")
# plot(fitMissensesAutismS)

# %%
# %%R -w 28 -h 28 -u cm
# ## SCZ LOF
# plot(fitLoFsczS)

# %%
# %%R -w 28 -h 28 -u cm
# ## SCZ Damaging
# load("/usr/data/Documents/SaveDataFromServer/rstan_scz_1500genes_LoF_missense_denovo.RData")
# summary(s)
# plot(s)
# Out:
# ...
# by .GlobalEnv when processing object ‘fitLoFscz_useDenovolyzeRmut’
